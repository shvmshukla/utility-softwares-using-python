# %%
import Image

# %%
import pytesseract

# %%
print pytesseract.image_to_string(Image.open('test1.jpg'))
# Out:
# The Perfect Ice Cream Sundae
#
# \‘ ’x
# . /
# é:
#
# Ice cream sundaes are delicious. There are so
# many different ingredients that can be used to
# make the perfect ice cream sundae. It is always best
# to start with 3 different ice cream flavors. Some
# favorite flavors are chocolate, vanilla, and
# strawberry. Next, sauces can be added. Ice cream
# connoisseurs may enjoy strawberry sauce on
# strawberry ice cream, chocolate sauce on chocolate
# ice cream, and marshmallow fluff on vanilla ice
# cream. As a final touch, add toppings. Chopped nuts
# and colorful sprinkles are a good combination.
#
# Before serving, do not forget to top with a cherry!

# %%
print pytesseract.image_to_string(Image.open('test2.jpg'))
# Out:
# Exa pie:
#
# Th rm ‘ . hr llW
# me to la outside. I la under
# the srinKler with m brother.
# We run through the water and
# scream each time! At night, I
# play hide and seeK with my
# friends. I usually hide behind a
# big bush. 1 love it when the
# weather is warm!

# %%
print pytesseract.image_to_string(Image.open('test3.jpeg'))
# Out:
# Tell me the things
# you've never said
# out loud.
#
# Show me the parts
# of you, you are not
# that proud of.
#
# . I wanna  :1. _ .. .
# I am just a man.
# I don't mind when
#
# you're with me.

# %%
print pytesseract.image_to_string(Image.open('test8.jpeg'))
# Out:
# SINGING BIRDS
#
# " SPOKEN ENGLISH & MIDI ’
#
# WW
